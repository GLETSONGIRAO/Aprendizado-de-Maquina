# %%
import sys
sys.path.append('../')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#exceção Cross Validation do sklearn
from sklearn.model_selection import cross_val_score 

from g_ml.utilidades.processamento import treino_teste
from g_ml.utilidades.processamento import escala_padrao

from g_ml.utilidades.metricas import ACC
from g_ml.utilidades.metricas import relatorio_classificacao
from g_ml.utilidades.metricas import ValCruzada

from g_ml.algoritmos.classificacao import RegressaoLogistica
from g_ml.algoritmos.classificacao import ADG
from g_ml.algoritmos.classificacao import NaiveBayesGaussiano

# %%
from sklearn.datasets import load_breast_cancer
X, y = load_breast_cancer(return_X_y=True)

# %%
# Separação em treino e teste
X_treino, X_teste, y_treino, y_teste = treino_teste(X, y, tamanho_teste = 0.33)

# %%
escalador_X = escala_padrao()

escalador_X.fit(X_treino)

X_treino_escalado = escalador_X.transform(X_treino)
X_teste_escalado = escalador_X.transform(X_teste)

# %%
## Modelo dumb para baseline

# %%
np.unique(y_treino, return_counts=True)
# Out:
# (array([0, 1]), array([134, 248], dtype=int64))

# %%
y_base = np.ones(len(y_teste))
print("A acurácia base de um modelo inocente é: {}".format(ACC(y_base, y_teste)))
# Out:
# A acurácia base de um modelo inocente é: 0.5828877005347594

# %% [markdown]
# # Regressão Logística com Gradiente Descendente

# %%
RL = RegressaoLogistica(t= 5000)
RL.fit(X_treino_escalado, y_treino)
y_pred = RL.predict(X_teste_escalado)
print(ACC(y_teste,y_pred))
# Out:
# 0.983957219251337

# %%
plt.plot(RL.custos)
plt.title("Curva de Aprendizagem")
plt.show()

# %%
scores = relatorio_classificacao(y_pred, y_teste)

# %%
scores.print_scores()
# Out:
# A acurácia do modelo é de: 0.983957219251337
# A precisão do modelo é de: 0.9818181818181818
# A revocacão do modelo é de: 0.9908256880733946
# O f1_score do modelo é de: 0.9863013698630138

# %%
scores.plot_scores()

# %%
## TESTE
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_treino_escalado, y_treino)
y_pred2 = model.predict(X_teste_escalado)
print(accuracy_score(y_pred2,y_teste))
# Out:
# 0.983957219251337

# %%
scores = relatorio_classificacao(y_pred2, y_teste)
scores.plot_scores()

# %% [markdown]
# **Regressão Logística utilizando VALIDAÇÃO CRUZADA**
#
# Obs: Ao reutilizar o objeto vc usamos os mesmos indices para outros X com o mesmo tamanho e outros modelos.

# %%
vc = ValCruzada(X_treino, part= 10)
vc.particionar(X_treino_escalado, y_treino)
vc.medir(RegressaoLogistica())
# Out:
# ..\g_ml\algoritmos\classificacao.py:25: RuntimeWarning: divide by zero encountered in log
#   custo =  np.mean(-y * np.log(y_pred) - (1-y) * np.log(1 - y_pred))
# Acurácia média é: 0.9554655870445343 e seu desvio padrão é: 0.033399105724060955
# Precisão média é: 0.9507408897817247 e seu desvio padrão é: 0.04849907203514693
# Revocacão média é: 0.9811736237144585 e seu desvio padrão é: 0.029028340763571966
# F1_score médio é: 0.964749657231913 e seu desvio padrão é: 0.02856750971194903

# %%
np.log(0)
# Out:
# <ipython-input-16-f6e7c0610b57>:1: RuntimeWarning: divide by zero encountered in log
#   np.log(0)
# -inf

# %% [markdown]
# # Análise de Discriminante Gaussiano

# %%
adg = ADG()
adg.fit(X_treino_escalado, y_treino)
y_pred = adg.predict(X_teste_escalado)
print(ACC(y_pred, y_teste))
# Out:
# 0.9732620320855615

# %%
scores = relatorio_classificacao(y_pred, y_teste)
scores.print_scores()
# Out:
# A acurácia do modelo é de: 0.9732620320855615
# A precisão do modelo é de: 0.9642857142857143
# A revocacão do modelo é de: 0.9908256880733946
# O f1_score do modelo é de: 0.9773755656108598

# %%
scores.plot_scores()

# %% [markdown]
# **ADG utilizando VALIDAÇÃO CRUZADA**

# %%
#vc = ValCruzada(X_treino, part= 10)
#vc.particionar(X_treino_escalado, y_treino)
vc.medir(ADG())
# Out:
# Acurácia média é: 0.942375168690958 e seu desvio padrão é: 0.01977230743263151
# Precisão média é: 0.9504261202731966 e seu desvio padrão é: 0.03336880348765962
# Revocacão média é: 0.963155366761064 e seu desvio padrão é: 0.036008785879871094
# F1_score médio é: 0.955660265437125 e seu desvio padrão é: 0.013197850615494413

# %% [markdown]
# # Naive Bayes Gaussiano

# %%
nbg = NaiveBayesGaussiano()
nbg.fit(X_treino_escalado, y_treino)
y_pred = nbg.predict(X_teste_escalado)
print(ACC(y_pred, y_teste))
# Out:
# 0.946524064171123

# %%
scores = relatorio_classificacao(y_pred, y_teste)
scores.print_scores()
# Out:
# A acurácia do modelo é de: 0.946524064171123
# A precisão do modelo é de: 0.9541284403669725
# A revocacão do modelo é de: 0.9541284403669725
# O f1_score do modelo é de: 0.9541284403669725

# %%
scores.plot_scores()

# %% [markdown]
# **NaiveBayesGaussiano utilizando VALIDAÇÃO CRUZADA**

# %%
#vc = ValCruzada(X_treino, part= 10)
#vc.particionar(X_treino_escalado, y_treino)
vc.medir(NaiveBayesGaussiano())
# Out:
# Acurácia média é: 0.9159244264507423 e seu desvio padrão é: 0.04389824939021981
# Precisão média é: 0.9258010825893269 e seu desvio padrão é: 0.05374519079163398
# Revocacão média é: 0.9415406112733107 e seu desvio padrão é: 0.06032884605698363
# F1_score médio é: 0.9319679838669728 e seu desvio padrão é: 0.04155261571894527

# %% [markdown]
# # KNN
